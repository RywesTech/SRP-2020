# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import time
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %%
df = pd.read_csv('data/flight.csv')
fig = go.FigureWidget()
#fig.add_trace(go.Scatter(x=df['ms'], y=df['0_ang_pos'], name='Ang Position', line=dict(color='firebrick', width=2)))
#fig.add_trace(go.Scatter(x=df['ms'], y=df['0_output'], name = 'TVC Angle', line=dict(color='royalblue', width=2)))
#fig.add_trace(go.Scatter(x=df['ms'], y=df['0_p'], name = 'P', line=dict(color='red', width=2)))
#fig.add_trace(go.Scatter(x=df['ms'], y=df['0_i'], name = 'I', line=dict(color='green', width=2)))
#fig.add_trace(go.Scatter(x=df['ms'], y=df['0_d'], name = 'D', line=dict(color='blue', width=2)))
fig.add_trace(go.Scatter(x=df['ms'], y=df['2_lin_accel'], name = 'Accel', line=dict(color='blue', width=2)))
fig.add_trace(go.Scatter(x=df['ms'], y=df['2_lin_vel'], name = 'Vel', line=dict(color='red', width=2)))
fig.add_trace(go.Scatter(x=df['ms'], y=df['2_lin_pos'], name = 'Alt', line=dict(color='green', width=2)))
fig.show()

max(df['2_lin_vel'])
# Out:
# <div>
#
#
#             <div id="36ae370d-036b-44a6-94a7-cac90f158eaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("36ae370d-036b-44a6-94a7-cac90f158eaf")) {
#                     Plotly.newPlot(
#                         '36ae370d-036b-44a6-94a7-cac90f158eaf',
# ...

# %%
import seaborn as sns
from scipy.ndimage.filters import gaussian_filter
data = pd.read_csv('data/opt_flight.csv',index_col=0)
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(data,vmin=-20,vmax=0)

# %%
import seaborn as sns
from scipy.ndimage.filters import gaussian_filter
data = pd.read_csv('data/opt_throttle_flight.csv',index_col=0)
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(data,vmin=-20,vmax=0)

# %%
data = pd.read_csv('data/opt_throttle_thrdat_flight.csv',index_col=0)
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(data,vmin=75,vmax=100)
